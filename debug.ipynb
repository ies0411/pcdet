# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_path ='./sample/image/0000/000102.png'
image = cv2.imread(img_path)

# %%
plt.subplots(1, 1, figsize=(15, 7))
plt.imshow(image)

# %%
# 143 4 Cyclist -1 -1 -10 450.73009706015335 176.91612863364116 472.29967972800563 203.75762738692595 1.2892372608184814 0.6178645491600037 1.7509485483169556 -9.796902 2.020375 47.475674 -4.702851847806249 
# 148 5 Cyclist -1 -1 -10 486.1724914141176 170.058783381236 515.3613777999755 199.5688133519327 1.6538771390914917 0.6659706234931946 1.7215945720672607 -6.458042 1.5588813 42.484367 1.4969286163661142 
# 2 2 Cyclist -1 -1 -10 57.90619674168831 177.23991084492874 87.92587907896421 206.83674122527242 1.5616111914373334 0.6055873498233671 1.7918824249286778 -32.996204 2.064276 44.28497 -4.492776559302117 
# 2 2 Pedestrian -1 -1 -10 761.0823456526349 142.5807759281826 930.5345668301369 374.0 1.1398794651031494 0.6946055889129639 1.849300742149353 1.7457684 1.6290978 5.655969 -1.4719975749638419 
# 2 1 Pedestrian -1 -1 -10 1143.4613594230932 148.82379354562752 1241.0 318.64053177582133 0.9270823958060321 0.6807720991538899 1.7488252910480662 6.4520574 1.5017127 7.845968 -1.3902373124252378 

# 43 2 Pedestrian -1 -1 -10 1172.072835 143.021182 1241.000000 302.953721 1.776573 0.629693 0.759035 7.116705 1.445540 8.410258 -3.202476
# 70 3 Pedestrian -1 -1 -10 752.981030 172.246431 781.978005 235.917591 1.765118 0.581367 0.583103 4.395482 1.748633 20.370298 -3.473060

# 1 2 Cyclist -1 -1 -10 109.176498 182.734843 141.019231 220.351099 1.821016 0.595142 1.825209 -24.459848 2.332391 36.368706 -3.280846 

x1, y1, x2, y2 =   646, 164, 662, 199

# 바운딩 박스 색상 및 두께 설정
color = (0, 255, 0)  # 초록색 (BGR 형식)
thickness = 2  # 선 두께

# 이미지에 바운딩 박스 그리기
image_with_bbox = cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)

# %%
plt.subplots(1, 1, figsize=(15, 7))
plt.imshow(image_with_bbox)

# %%
# import torch
# from torch.utils.data import Dataset, DataLoader

# class CustomDataset(Dataset):
#     def __init__(self, data):
#         self.data = data

#     def __len__(self):
#         return 3

#     def __getitem__(self, idx):
#         print(f'idx : {idx}')
#         # sample = self.data[idx]
#         # return sample
#         return idx

# # 더미 데이터 생성
# data = torch.randn(10, 3, 32, 32)  # 예시로 100개의 3채널 32x32 크기의 이미지 데이터 생성

# # CustomDataset 클래스를 사용하여 데이터셋 객체 생성
# dataset = CustomDataset(data)

# # DataLoader를 사용하여 데이터 로더 생성
# # 배치 크기를 16으로 설정하고 셔플 옵션을 True로 설정
# dataloader = DataLoader(dataset, batch_size=1, shuffle=False)

# # 데이터 로더를 통해 데이터를 반복하여 로드
# for batch in dataset:
#     print(batch)
#     # 이곳에서 배치(batch)에 대한 작업을 수행합니다.
#     # 예를 들어, 모델에 배치를 전달하여 예측을 수행할 수 있습니다.
#     # print("배치 데이터 크기:", batch.size())

# %%
# tracking_result = [[]]

# len(tracking_result)

# %%
a = [2]

# %%
from collections import OrderedDict
my_dict = OrderedDict()

# %%
my_dict['1'] = 1
my_dict['2'] = 2
my_dict['3'] = 3
print(my_dict.get("5"))
# Out:
# None

# %%
d = {}
d['1']=1
d['2']=1
d

# for k,v in my_dict.items():
#     print(k)
#     print(v)
#     print("==")
# Out:
# {'1': 1, '2': 1}

# %%
id = a = 1

# %%
import numpy as np
a = np.array([1,2,3,4,5])

# %%
a[:-1]
# Out:
# array([1, 2, 3, 4])
